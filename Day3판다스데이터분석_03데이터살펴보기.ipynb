# %% [markdown]
# <a href="https://colab.research.google.com/github/wnsmir/DSBA5/blob/main/Day3%E1%84%91%E1%85%A1%E1%86%AB%E1%84%83%E1%85%A1%E1%84%89%E1%85%B3%E1%84%83%E1%85%A6%E1%84%8B%E1%85%B5%E1%84%90%E1%85%A5%E1%84%87%E1%85%AE%E1%86%AB%E1%84%89%E1%85%A5%E1%86%A8_03%E1%84%83%E1%85%A6%E1%84%8B%E1%85%B5%E1%84%90%E1%85%A5%E1%84%89%E1%85%A1%E1%86%AF%E1%84%91%E1%85%A7%E1%84%87%E1%85%A9%E1%84%80%E1%85%B5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # **03 데이터 살펴보기**

# %% [markdown]
# # 1. 데이터프레임의 구조
# * 자동차 연비(auto mpg) 데이터셋
# * [표] UCI 데이터셋- "auto mpg" 상세 항목
#
# |No|속성(attributes)|데이터 상세(범위)|
# |------|---|---|
# |1|mpg(연비)|연속값|
# |2|cylinders(실린더 수)|이산값(예: 3, 4, 6, 8)|
# |3|displacement(배기량)|연속값|
# |4|horsepower(출력)|연속값|
# |5|weight(차종)|연속값|
# |6|acceleration(가속능력)|연속값|
# |7|model_year(출시년도)|이산값(예: 70, 71, 80, 81)|
# |8|orgin(제조국)|이산값(예: 1(USA), 2(EU), 3(JPN)|
# |9|name(모델명)|문자열|
#
#
# ## 1-1 데이터 내용 미리보기
#
# ```
# * 앞부분 미리보기: DataFrame 객체.head(n)
# * 뒷부분 미리보기: DataFrame 객체.tail(n)
# ```
# * 여기서 정수 n을 입력하지 않으면 5개의 행을 보여준다,(디폴트값: n=5)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
file_path = '/content/drive/MyDrive/DSBA파이썬판다스데이터분석/3장자료/auto-mpg.csv'
import pandas as pd
df = pd.read_csv(file_path, header=None)
df.head()
# Out:
#       0  1      2      3       4     5   6  7                          8
# 0  18.0  8  307.0  130.0  3504.0  12.0  70  1  chevrolet chevelle malibu
# 1  15.0  8  350.0  165.0  3693.0  11.5  70  1          buick skylark 320
# 2  18.0  8  318.0  150.0  3436.0  11.0  70  1         plymouth satellite
# 3  16.0  8  304.0  150.0  3433.0  12.0  70  1              amc rebel sst
# 4  17.0  8  302.0  140.0  3449.0  10.5  70  1                ford torino

# %%
df.columns = ['mpg','cylinders','displacement','horsepower','weight',
              'acceleration','model year','origin','name']
df
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  \
# 0    18.0          8         307.0      130.0  3504.0          12.0
# 1    15.0          8         350.0      165.0  3693.0          11.5
# 2    18.0          8         318.0      150.0  3436.0          11.0
# 3    16.0          8         304.0      150.0  3433.0          12.0
# 4    17.0          8         302.0      140.0  3449.0          10.5
# ..    ...        ...           ...        ...     ...           ...
# 393  27.0          4         140.0      86.00  2790.0          15.6
# 394  44.0          4          97.0      52.00  2130.0          24.6
# 395  32.0          4         135.0      84.00  2295.0          11.6
# 396  28.0          4         120.0      79.00  2625.0          18.6
# 397  31.0          4         119.0      82.00  2720.0          19.4
#
#      model year  origin                       name
# 0            70       1  chevrolet chevelle malibu
# ...

# %%
# <예제 3-1> 데이터 살펴보기
# -*- coding: utf-8 -*-

import pandas as pd

# read_csv() 함수로 df 생성
df = pd.read_csv('./auto-mpg.csv', header=None)

# 열 이름을 지정
df.columns = ['mpg','cylinders','displacement','horsepower','weight',
              'acceleration','model year','origin','name']

# 데이터프레임 df의 내용을 일부 확인
print(df.head())     # 처음 5개의 행
print('\n')
print(df.tail())     # 마지막 5개의 행
# Out:
#     mpg  cylinders  displacement horsepower  weight  acceleration  model year  \
# 0  18.0          8         307.0      130.0  3504.0          12.0          70
# 1  15.0          8         350.0      165.0  3693.0          11.5          70
# 2  18.0          8         318.0      150.0  3436.0          11.0          70
# 3  16.0          8         304.0      150.0  3433.0          12.0          70
# 4  17.0          8         302.0      140.0  3449.0          10.5          70
#
#    origin                       name
# 0       1  chevrolet chevelle malibu
# 1       1          buick skylark 320
# 2       1         plymouth satellite
# 3       1              amc rebel sst
# 4       1                ford torino
#
#
#       mpg  cylinders  displacement horsepower  weight  acceleration  \
# 393  27.0          4         140.0      86.00  2790.0          15.6
# 394  44.0          4          97.0      52.00  2130.0          24.6
# ...

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## 1-2 데이터 요약 정보 확인하기
# ### 1. 데이터프레임의 크기(행, 열)
#
# ```
# 데이터프레임의 크기 확인: DataFrame 객체.shape
# ```

# %%
# df의 모양과 크기 확인: (행의 개수, 열의 개수)를 투플로 반환
print(df.shape)
# Out:
# (398, 9)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### 2. 데이터프레임의 기본 정보
#
# ```
# 데이터프레임의 기본 정보 출력: DataFrame 객체.info()
# ```

# %%
# 데이터프레임 df의 내용 확인
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 398 entries, 0 to 397
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   mpg           398 non-null    float64
#  1   cylinders     398 non-null    int64
#  2   displacement  398 non-null    float64
#  3   horsepower    398 non-null    object
#  4   weight        398 non-null    float64
#  5   acceleration  398 non-null    float64
#  6   model year    398 non-null    int64
#  7   origin        398 non-null    int64
#  8   name          398 non-null    object
# dtypes: float64(4), int64(3), object(2)
# memory usage: 28.1+ KB
# None

# %% [markdown]
# * [참고] 판다스 자료형의 종류
#
# |판다스 자료형|파이썬 자료형|비고|
# |------|---|---|
# |int64|int|정수형 데이터|
# |flote64|cylfloat|실수형 데이터(소수점이 있는 경우)|
# |object|string|문자형 데이터|
# |datetime64, timedelta64|없음(datetime 라이브러리 활용)|시간 데이터|

# %%
# 데이터프레임 df의 자료형 확인
print(df.dtypes)
print('\n')

# 시리즈(mog 열)의 자료형 확인
print(df.mpg.dtypes)
# Out:
# mpg             float64
# cylinders         int64
# displacement    float64
# horsepower       object
# weight          float64
# acceleration    float64
# model year        int64
# origin            int64
# name             object
# dtype: object
#
#
# float64

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### 3. 데이터프레임의 기술 통계 정보 요약
#
# ```
# 데이터프레임의 기술 통계 정보 요약: DataFrame 객체.describe()
# ```
# * 산술 데이터가 아닌 열에 대한 정보를 포함하고 싶을 때는 include='all' 옵션을 추가

# %%
# 데이터프레임 df의 기술통계 정보 확인
print(df.describe())
print('\n')
print(df.describe(include='all'))
# Out:
#               mpg   cylinders  displacement       weight  acceleration  \
# count  398.000000  398.000000    398.000000   398.000000    398.000000
# mean    23.514573    5.454774    193.425879  2970.424623     15.568090
# std      7.815984    1.701004    104.269838   846.841774      2.757689
# min      9.000000    3.000000     68.000000  1613.000000      8.000000
# 25%     17.500000    4.000000    104.250000  2223.750000     13.825000
# 50%     23.000000    4.000000    148.500000  2803.500000     15.500000
# 75%     29.000000    8.000000    262.000000  3608.000000     17.175000
# max     46.600000    8.000000    455.000000  5140.000000     24.800000
#
#        model year      origin
# count  398.000000  398.000000
# mean    76.010050    1.572864
# std      3.697627    0.802055
# min     70.000000    1.000000
# 25%     73.000000    1.000000
# 50%     76.000000    1.000000
# 75%     79.000000    2.000000
# max     82.000000    3.000000
#
#
# ...

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## 1-3 데이터 개수 확인
# ### 1. 각 열의 데이터 개수
#
# ```
# 열 데이터 개수 확인: DataFrame 객체.count()
# ```

# %%
# <예제 3-2> 데이터 개수 확인
# -*- coding: utf-8 -*-

import pandas as pd

# read_csv() 함수로 df 생성
df = pd.read_csv('./auto-mpg.csv', header=None)

# 열 이름을 지정
df.columns = ['mpg','cylinders','displacement','horsepower','weight',
              'acceleration','model year','origin','name']

# 데이터프레임 df의 각 열이 가지고 있는 원소 개수 확인
print(df.count())
print('\n')

# df.count()가 반환하는 객체 타입 출력
print(type(df.count()))
# Out:
# mpg             398
# cylinders       398
# displacement    398
# horsepower      398
# weight          398
# acceleration    398
# model year      398
# origin          398
# name            398
# dtype: int64
#
#
# <class 'pandas.core.series.Series'>

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### 2. 각 열의 고윳값 개수
#
# ```
# 열 데이터의 고윳값 개수: DataFrame 객체["열 이름"].value_count()
# ```

# %%
# 데이터프레임 df의 특정 열이 가지고 있는 고유값 확인
unique_values = df['origin'].value_counts()
print(unique_values)
print('\n')

# value_counts 메소드가 반환하는 객체 타입 출력
print(type(unique_values))
# Out:
# 1    249
# 3     79
# 2     70
# Name: origin, dtype: int64
#
#
# <class 'pandas.core.series.Series'>

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # 2. 통계 함수 적용
# ## 2-1 평균값
#
# ```
# * 모든 열의 평균값: DataFrame 객체.mean()
# * 특정 열의 평균값: DataFrame 객체["열 이름"].mean()
# ```

# %%
# <예제 3-3> 통계 함수
# -*- coding: utf-8 -*-

import pandas as pd

# read_csv() 함수로 df 생성
df = pd.read_csv('./auto-mpg.csv', header=None)

# 열 이름을 지정
df.columns = ['mpg','cylinders','displacement','horsepower','weight',
              'acceleration','model year','origin','name']

# 평균값
print(df.mean())
print('\n')
print(df['mpg'].mean())
print(df.mpg.mean())
print('\n')
print(df[['mpg','weight']].mean())
# Out:
# mpg               23.514573
# cylinders          5.454774
# displacement     193.425879
# weight          2970.424623
# acceleration      15.568090
# model year        76.010050
# origin             1.572864
# dtype: float64
#
#
# 23.514572864321607
# 23.514572864321607
#
#
# mpg         23.514573
# weight    2970.424623
# dtype: float64
# <ipython-input-3-3a1e9d19d949>:14: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   print(df.mean())

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## 2-2 중간값
#
# ```
# * 모든 열의 중간값: DataFrame 객체.median()
# * 특정 열의 중간값: DataFrame 객체["열 이름"].median()
# ```

# %%
# 중간값
print(df.median())
print('\n')
print(df['mpg'].median())
# Out:
# mpg               23.0
# cylinders          4.0
# displacement     148.5
# weight          2803.5
# acceleration      15.5
# model year        76.0
# origin             1.0
# dtype: float64
#
#
# 23.0
# <ipython-input-4-392f16fcc621>:2: FutureWarning: The default value of numeric_only in DataFrame.median is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   print(df.median())

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## 2-3 최댓값
#
# ```
# * 모든 열의 최댓값: DataFrame 객체.max()
# * 특정 열의 최댓값: DataFrame 객체["열 이름"].max()
# ```

# %%
# 최댓값
print(df.max())
print('\n')
print(df['mpg'].max())
# Out:
# mpg                         46.6
# cylinders                      8
# displacement               455.0
# horsepower                     ?
# weight                    5140.0
# acceleration                24.8
# model year                    82
# origin                         3
# name            vw rabbit custom
# dtype: object
#
#
# 46.6

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## 2-4 최솟값
#
# ```
# * 모든 열의 최솟값: DataFrame 객체.min()
# * 특정 열의 최솟값: DataFrame 객체["열 이름"].min()
# ```

# %%
# 최솟값
print(df.min())
print('\n')
print(df['mpg'].min())
# Out:
# mpg                                 9.0
# cylinders                             3
# displacement                       68.0
# horsepower                        100.0
# weight                           1613.0
# acceleration                        8.0
# model year                           70
# origin                                1
# name            amc ambassador brougham
# dtype: object
#
#
# 9.0

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## 2-5 표준편차
#
# ```
# * 모든 열의 표준편차: DataFrame 객체.std()
# * 특정 열의 표준편차: DataFrame 객체["열 이름"].std()
# ```

# %%
# 표준편차
print(df.std())
print('\n')
print(df['mpg'].std())
# Out:
# mpg               7.815984
# cylinders         1.701004
# displacement    104.269838
# weight          846.841774
# acceleration      2.757689
# model year        3.697627
# origin            0.802055
# dtype: float64
#
#
# 7.815984312565782
# <ipython-input-7-edd9452e1c33>:2: FutureWarning: The default value of numeric_only in DataFrame.std is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   print(df.std())

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## 2-6 상관계수
#
# ```
# * 모든 열의 상관계수: DataFrame 객체.corr()
# * 특정 열의 상관계수: DataFrame 객체["열 이름"].corr()
# ```

# %%
# 상관계수
print(df.corr())
print('\n')
print(df[['mpg','weight']].corr())
# Out:
#                    mpg  cylinders  displacement    weight  acceleration  \
# mpg           1.000000  -0.775396     -0.804203 -0.831741      0.420289
# cylinders    -0.775396   1.000000      0.950721  0.896017     -0.505419
# displacement -0.804203   0.950721      1.000000  0.932824     -0.543684
# weight       -0.831741   0.896017      0.932824  1.000000     -0.417457
# acceleration  0.420289  -0.505419     -0.543684 -0.417457      1.000000
# model year    0.579267  -0.348746     -0.370164 -0.306564      0.288137
# origin        0.563450  -0.562543     -0.609409 -0.581024      0.205873
#
#               model year    origin
# mpg             0.579267  0.563450
# cylinders      -0.348746 -0.562543
# displacement   -0.370164 -0.609409
# weight         -0.306564 -0.581024
# acceleration    0.288137  0.205873
# model year      1.000000  0.180662
# origin          0.180662  1.000000
#
#
#              mpg    weight
# mpg     1.000000 -0.831741
# weight -0.831741  1.000000
# ...

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # 3. 판다스 내장 그래프 도구 활용
# * [표] 판다스 내장 plot() 메소드 - 그래프 종류
#
# |kind 옵션|설명|kind 옵션|설명|
# |------|---|---|---|
# |'line'|선 그래프|'kde'|커널 밀도 그래프|
# |'bar'|수직 막대 그래프|'area'|면적 그래프|
# |'barh'|수평 막대 그래프|'pie'|파이 그래프|
# |'his'|히스토그램|'scatter'|산점도 그래프|
# |'box'|박스플롯|'hexbin'|고밀도 산점도 그래프|
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### 1. 선 그래프
#
# ```
# 선 그래프: DataFrame 객체.plot()
# ```

# %%
# <예제 3-4> 선 그래프 그리기
# -*- coding: utf-8 -*-

import pandas as pd

df = pd.read_excel('./남북한발전전력량.xlsx', engine='openpyxl')  # 데이터프레임 변환

df_ns = df.iloc[[0, 5], 3:]            # 남한, 북한 발전량 합계 데이터만 추출
df_ns.index = ['South','North']        # 행 인덱스 변경
df_ns.columns = df_ns.columns.map(int) # 열 이름의 자료형을 정수형으로 변경
print(df_ns.head())
print('\n')

# 선 그래프 그리기
df_ns.plot()
# Out:
#        1991  1992  1993  1994  1995  1996  1997  1998  1999  2000  ...  2007  \
# South  1186  1310  1444  1650  1847  2055  2244  2153  2393  2664  ...  4031
# North   263   247   221   231   230   213   193   170   186   194  ...   236
#
#        2008  2009  2010  2011  2012  2013  2014  2015  2016
# South  4224  4336  4747  4969  5096  5171  5220  5281  5404
# North   255   235   237   211   215   221   216   190   239
#
# [2 rows x 26 columns]
# <Axes: >

# %% [markdown]
# * 행 인덱스(df_ns의 행 인덱스;'South','North')를 x축 데이터로 적용
# * 시간의 흐름에 따른 연도별 발전량 변화 추이를 보기 위해
#   * 연도 값을 x축으로 표시(행, 열 전치)

# %%
# 행, 열 전치하여 다시 그리기
tdf_ns = df_ns.T
print(tdf_ns.head())
print('\n')
tdf_ns.plot()
# Out:
#      South North
# 1991  1186   263
# 1992  1310   247
# 1993  1444   221
# 1994  1650   231
# 1995  1847   230
# <Axes: >

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### 2. 막대 그래프
#
# ```
# 막대 그래프: DataFrame 객체.plot(kind='bar')
# ```

# %%
# <예제 3-5> 막대 그래프
# -*- coding: utf-8 -*-

import pandas as pd

df = pd.read_excel('./남북한발전전력량.xlsx', engine='openpyxl')  # 데이터프레임 변환

df_ns = df.iloc[[0, 5], 3:]            # 남한, 북한 발전량 합계 데이터만 추출
df_ns.index = ['South','North']        # 행 인덱스 변경
df_ns.columns = df_ns.columns.map(int) # 열 이름의 자료형을 정수형으로 변경

# 행, 열 전치하여 막대 그래프 그리기
tdf_ns = df_ns.T
print(tdf_ns.head())
print('\n')
tdf_ns.plot(kind='bar')
# Out:
#      South North
# 1991  1186   263
# 1992  1310   247
# 1993  1444   221
# 1994  1650   231
# 1995  1847   230
# <Axes: >

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### 3. 히스토그램
#
# ```
# 히스토그램: DataFrame 객체.plot(kind='hist')
# ```

# %%
# colab에서 히스토그램 에러(Jupyter Notebook에서 run한 결과)
# <예제 3-6> 히스토그램
# -*- coding: utf-8 -*-

#import pandas as pd

#df = pd.read_excel('./남북한발전전력량.xlsx', engine='openpyxl')  # 데이터프레임 변환

#df_ns = df.iloc[[0, 5], 3:]            # 남한, 북한 발전량 합계 데이터만 추출
#df_ns.index = ['South','North']        # 행 인덱스 변경
#df_ns.columns = df_ns.columns.map(int) # 열 이름의 자료형을 정수형으로 변경

# 행, 열 전치하여 히스토그램 그리기
#tdf_ns = df_ns.T
#tdf_ns.plot(kind='hist')

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### 4. 산점도
#
# ```
# 산점도: DataFrame 객체.plot(kind='scatter')
# ```

# %%
# -*- coding: utf-8 -*-

import pandas as pd

# read_csv() 함수로 df 생성
df = pd.read_csv('./auto-mpg.csv', header=None)

# 열 이름을 지정
df.columns = ['mpg','cylinders','displacement','horsepower','weight',
              'acceleration','model year','origin','name']

# 2개의 열을 선택하여 산점도 그리기
df.plot(x='weight',y='mpg', kind='scatter')
# Out:
# <Axes: xlabel='weight', ylabel='mpg'>

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### 5. 박스 플롯
#
# ```
# 박스 플롯: DataFrame 객체.plot(kind='box')
# ```

# %%
# <예제 3-8> 박스 플롯
# -*- coding: utf-8 -*-

import pandas as pd

# read_csv() 함수로 df 생성
df = pd.read_csv('./auto-mpg.csv', header=None)

# 열 이름을 지정
df.columns = ['mpg','cylinders','displacement','horsepower','weight',
              'acceleration','model year','origin','name']

# 열을 선택하여 박스 플롯 그리기
df[['mpg','cylinders']].plot(kind='box')
# Out:
# <Axes: >

# %% [markdown]
# ![image.png](data:image/png;base64,...)
